# %% [markdown]
# <a href="https://colab.research.google.com/github/beryan-a/machine-learning-studies/blob/main/1-python-basics/1_2_3_variables_numbers_str_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
60/2
# Out:
# 30.0

# %%
60*5
# Out:
# 300

# %% [markdown]
# **DATA TYPE:**
#
#   - NUMBERS
#
#     - integer(int)
#     - float(kesirli sayılar için)
#   - STRING

# %% [markdown]
# # **VARIABLES**

# %% [markdown]
# variables => store data

# %%
age = 50

# %%
age
# Out:
# 50

# %% [markdown]
# ------------------------------------

# %% [markdown]
# # **INTEGERS**

# %%
#int -> integer

# %%
type(10)
# Out:
# int

# %%
type(age*5)
# Out:
# int

# %%
type(-1000)
# Out:
# int

# %%
x= -1000

# %%
type(x)
# Out:
# int

# %% [markdown]
# ---------------------------------------------------------

# %% [markdown]
# OPERATIONS
#
# **  -> for exponents
#
# % -> reaminder

# %% [markdown]
# # **FLOAT**

# %%
#float -> floating point

# %%
type(3.14)
# Out:
# float

# %%
pi=3.14

# %%
pi*2
# Out:
# 6.28

# %%
type(pi)
# Out:
# float

# %%
myFloat=1.34432688765415454

# %%
#camelCase
#snake_case

# %%
type(myFloat)
# Out:
# float

# %%
40/4
# Out:
# 10.0

# %%
type(40/4)
# Out:
# float

# %% [markdown]
# integer/integer=float

# %%
4.0/4.0
# Out:
# 1.0

# %%
4*4
# Out:
# 16

# %%
2*2.5
# Out:
# 5.0

# %%
type(4*4)
# Out:
# int

# %%
type(2.2*2)
# Out:
# float

# %%
2-10*2 #işlem önceliği dikkate alınır!
# Out:
# -18

# %%
2**5 #** üssü anlamında
# Out:
# 32

# %%
10%2
# Out:
# 0

# %%
10%3 #remainder (kalan)
# Out:
# 1

# %%
10%4
# Out:
# 2

# %% [markdown]
# # **STRINGS**

# %%
"HELLO WORLD"
# Out:
# 'HELLO WORLD'

# %%
print("python")
# Out:
# python

# %%
'python'
# Out:
# 'python'

# %%
print('hey')
# Out:
# hey

# %%
name="sam"

# %%
name
# Out:
# 'sam'

# %%
type(name) #str = string
# Out:
# str

# %% [markdown]
# string içerisinde tek tırnak kullanılacak olan durumlarda çift tırnak tercih edilir.

# %%
"atıl's res"
# Out:
# "atıl's res"

# %%
'atıl's res'
# Out:
#   File "/tmp/ipython-input-266-2335106441.py", line 1
#     'atıl's res'
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name="beryan"

# %%
name.capitalize() #capitalize: ilk harfini büyük
# Out:
# 'Beryan'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
name
# Out:
# 'beryan'

# %%
help(name.capitalize) #using help tells you what the function does
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name
# Out:
# 'beryan'

# %%
name.count("b") #shows the # of b in name
# Out:
# 1

# %%
name.count("y")
# Out:
# 1

# %%
name.upper()
# Out:
# 'BERYAN'

# %%
name
# Out:
# 'beryan'

# %%
x=10
y=5

# %%
x+y
# Out:
# 15

# %%
z=x+y

# %%
z
# Out:
# 15

# %%
nameUpper= name.upper()

# %%
nameUpper
# Out:
# 'BERYAN'

# %%
name
# Out:
# 'beryan'

# %%
print(name.upper())
# Out:
# BERYAN

# %%
len(name) # length
# Out:
# 6

# %%
print("atil samancıoğlu")
# Out:
# atil samancıoğlu

# %%
print("atil \nsamancıoğlu") # \n -> new line
# Out:
# atil
# samancıoğlu

# %%
#escape characters
# \n -> new line
# \t -> tab

# %%
print("atıl \tsamancıoğlu")
# Out:
# atıl 	samancıoğlu

# %% [markdown]
# # **INDEX**

# %%
myString="hello python"

# %%
myString[4], myString[0]
# Out:
# ('o', 'h')

# %%
myString[11]
# Out:
# 'n'

# %%
myString
# Out:
# 'hello python'

# %%
len(myString)
# Out:
# 12

# %%
len(myString)-1
# Out:
# 11

# %%
myName="james hetfield"

# %%
myName[len(myName)-1]
# Out:
# 'd'

# %%
myName[-1] , myName[-2] #starting from the end
# Out:
# ('d', 'l')

# %%
barcode = "ABCDE123123982"

# %%
barcode[0]
# Out:
# 'A'

# %%
"a"+"b"
# Out:
# 'ab'

# %%
name= "atıl"

# %%
surname="samancıoğlu"

# %%
fullname= name+ " " +surname

# %%
fullname
# Out:
# 'atıl samancıoğlu'

# %%
fullname*5 #string allows multiplying and addition
# Out:
# 'atıl samancıoğluatıl samancıoğluatıl samancıoğluatıl samancıoğluatıl samancıoğlu'

# %%
100*"a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
fullname/5, fullname-5 # string does not allow dividition and substraction
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-308-2983191165.py in <cell line: 0>()
# ----> 1 fullname/5, fullname-5 # string does not allow dividition and substraction
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[0]+barcode[1]+barcode[2]
# Out:
# 'ABC'

# %%
#slicing, starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
#barcode[starting index : stopping index : stepping index]

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode[::2] #ikişer ikişer atlayarak ilerler
# Out:
# 'ACE2138'

# %%
barcode[::3] # üçer üçer atlar
# Out:
# 'AD228'

# %%
barcode[3:5:] , barcode[3:5]
# Out:
# ('DE', 'DE')

# %%
barcode[1:9:2]
# Out:
# 'BD13'

# %%
barcode[::-1] #reverses the string
# Out:
# '289321321EDCBA'

# %%
name = "atıl samancıoğlu"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(...) method of builtins.str instance
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.

# %%
name.index("s")
# Out:
# 5

# %%
name.split()
# Out:
# ['atıl', 'samancıoğlu']

# %%
type(name.split())
# Out:
# list

# %% [markdown]
# # **LIST**

# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split()) #list
# Out:
# list

# %%
myString
# Out:
# 'hello python'

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0]="a" #tek eleman değişimini desteklemez

# %%
#immutable - immutability (değişmezlik)

# %%
myString= "atil"

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList=[x, y, z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
type(myList[0])
# Out:
# int

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,40,50,60,70]

# %%
myList[0] = 100 #listde index değiştirilebilir

# %%
 #mutable , mutability (değiştirebilirlik)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
len(myList)
# Out:
# 7

# %%
myList[len(myList)-1]
# Out:
# 70

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
myList.append(1) #adds 1 to the end

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 1]

# %%
myList.count(20) #how many 20 i have in the list
# Out:
# 1

# %%
myList.count(25) #how many 25 i have in the list
# Out:
# 0

# %%
myList.index(40)
# Out:
# 3

# %%
help(myList.insert) # adds an object to the index
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList.insert(2,35) #adds 35 to the index 2

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 1]

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 1]

# %%
myList.pop() #removes last element
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70]

# %%
myList.remove(40) #removes 40

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70]

# %%
myList.reverse() #reverses the list

# %%
myList
# Out:
# [70, 60, 50, 30, 35, 20, 100]

# %%
myList.sort() #sıralama yapar

# %%
myList
# Out:
# [20, 30, 35, 50, 60, 70, 100]

# %%
x = input("enter x")
# Out:
# enter x10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y:") #input - kullanıcıdan veri istenir
# Out:
# enter y:20

# %%
y
# Out:
# '20'

# %%
z = input("enter z:")
# Out:
# enter z:30

# %%
z
# Out:
# '30'

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]*2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %% [markdown]
# *VERİ TİPİ DÖNÜŞTÜRME*

# %%
myInteger = 50

# %%
str(myInteger) #integer -> string
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString) #string -> integer
# Out:
# 40

# %%
float(myString) #string -> float
# Out:
# 40.0

# %%
myString = "python"

# %%
#int(myString)  #not available

# %%
#float(myString)  #not available

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1])*2
# Out:
# 40

# %%
str(inputList)
# Out:
# "['10', '20', '30']"

# %%
nameList = ["atil","atlas","a","b"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [3.14,2.5,10.2,100.123]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["atil",100,3.14] #python allows

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1 / 5

# %%
mixedList
# Out:
# ['atil', 100, 3.14]

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %% [markdown]
# - NESTED LIST: List inside list

# %%
myNestedList = [10,20,3.14,"atil",[1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'atil'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
smallList[1]
# Out:
# 2

# %%
myNestedList[4][1] #2
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
