# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([12, 35, 76, 83, 12, 30, 28,  3, 25, 36, 99, 61, 17, 58, 98, 51,  4,
#        28, 46, 37])

# %%
new_array > 25
# Out:
# array([False,  True,  True,  True, False,  True,  True, False, False,
#         True,  True,  True, False,  True,  True,  True, False,  True,
#         True,  True])

# %%
new_array[new_array > 25]
# Out:
# array([35, 76, 83, 30, 28, 36, 99, 61, 58, 98, 51, 28, 46, 37])

# %%
new_array[new_array < 25]
# Out:
# array([12, 12,  3, 17,  4])

# %%
#TRANSPOSE & RESHAPE

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])

# %%
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array.transpose() #turn the rows into columns
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.T #different syntax
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
random_array = np.random.random((6,1))

# %%
random_array
# Out:
# array([[0.13058418],
#        [0.32052133],
#        [0.21403352],
#        [0.4627354 ],
#        [0.1101682 ],
#        [0.49698449]])

# %%
random_array.shape
# Out:
# (6, 1)

# %%
random_array.reshape(2,3)
# Out:
# array([[0.13058418, 0.32052133, 0.21403352],
#        [0.4627354 , 0.1101682 , 0.49698449]])

# %%
random_array.reshape(3,2)
# Out:
# array([[0.13058418, 0.32052133],
#        [0.21403352, 0.4627354 ],
#        [0.1101682 , 0.49698449]])

# %%
# z-score

# %%
data = np.array([10,12,13,15,18,25,100,105])

# %%
#outlier

# %%
mean = np.mean(data)

# %%
mean
# Out:
# np.float64(37.25)

# %%
data.sum() / len(data)
# Out:
# np.float64(37.25)

# %%
std = np.std(data) #standart sapma

# %%
std
# Out:
# np.float64(37.9333296719389)

# %%
z_scores = (data - mean) / std

# %%
z_scores
# Out:
# array([-0.71836562, -0.66564154, -0.6392795 , -0.58655542, -0.50746929,
#        -0.322935  ,  1.65421809,  1.78602829])

# %%
z_scores[z_scores > 1]
# Out:
# array([1.65421809, 1.78602829])

# %%
data[z_scores > 1]
# Out:
# array([100, 105])

# %%
#MATH EQUATIONS

# %%
#2x + 3y = 8 and 5x + 7y = 19

# %%
A = np.array([[2,3],[5,7]]) #coefficient

# %%
B = np.array([8,19]) #constant

# %%
soultion = np.linalg.solve(A,B) # linalg = linear algebra

# %%
soultion # x=1 y=2
# Out:
# array([1., 2.])
