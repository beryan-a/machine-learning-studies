# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 0.14692148, -1.0378217 , -0.90431902],
#        [ 1.35616977, -0.46148317,  0.15849841],
#        [-1.19499254, -0.72373652, -1.19381467],
#        [-0.98122861,  0.73900791, -0.99768335]])

# %%
#data_frame = pd.Series(data) #hata verecek çünkü series must be 1-dimensional

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.146921 -1.037822 -0.904319
# 1  1.356170 -0.461483  0.158498
# 2 -1.194993 -0.723737 -1.193815
# 3 -0.981229  0.739008 -0.997683

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
data_frame[0]
# Out:
# 0    0.146921
# 1    1.356170
# 2   -1.194993
# 3   -0.981229
# Name: 0, dtype: float64

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df= pd.DataFrame(data, index = ["Atil", "Zeynep", "Atlas", "Mehmet"],columns=["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df["Age"]
# Out:
# Atil     -1.037822
# Zeynep   -0.461483
# Atlas    -0.723737
# Mehmet    0.739008
# Name: Age, dtype: float64

# %%
new_df["Salary"]
# Out:
# Atil      0.146921
# Zeynep    1.356170
# Atlas    -1.194993
# Mehmet   -0.981229
# Name: Salary, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Atil   -1.037822  0.146921
# Zeynep -0.461483  1.356170
# Atlas  -0.723737 -1.194993
# Mehmet  0.739008 -0.981229

# %%
#sadece row almak istersem

# %%
new_df.loc["Atil"] #atilin satırını getiirecek
# Out:
# Salary       0.146921
# Age         -1.037822
# Seniority   -0.904319
# Name: Atil, dtype: float64

# %%
new_df.iloc[0] #atilin satırını getirir ama index aracılığıyla
# Out:
# Salary       0.146921
# Age         -1.037822
# Seniority   -0.904319
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df.iloc[:,2] #seniority=[2] kolonudaki (:) herşeyi getirecek
# Out:
# Atil     -0.904319
# Zeynep    0.158498
# Atlas    -1.193815
# Mehmet   -0.997683
# Name: Seniority, dtype: float64

# %%
new_df.iloc[1,2] #zeynep'in seniority
# Out:
# np.float64(0.15849840782320554)

# %% [markdown]
# # *DATA MANIPULATION (DATA MANİPÜLASYONU)*

# %%
new_df["Extra"]= 10 #hepsine 10 atayacak

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.146921 -1.037822  -0.904319     10
# Zeynep  1.356170 -0.461483   0.158498     10
# Atlas  -1.194993 -0.723737  -1.193815     10
# Mehmet -0.981229  0.739008  -0.997683     10

# %%
new_df.drop("Extra", axis=1) #drop "extra" removes that column with name extra , and the axis 1 means columns, axis 0 means row
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df # the extra column is not removed permanently
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.146921 -1.037822  -0.904319     10
# Zeynep  1.356170 -0.461483   0.158498     10
# Atlas  -1.194993 -0.723737  -1.193815     10
# Mehmet -0.981229  0.739008  -0.997683     10

# %%
new_df.drop("Extra", axis=1, inplace=True) #with inplace the removing is permanent

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df["Mehmet"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Mehmet
# Atil    0.146921 -1.037822  -0.904319      10
# Zeynep  1.356170 -0.461483   0.158498      10
# Atlas  -1.194993 -0.723737  -1.193815      10
# Mehmet -0.981229  0.739008  -0.997683      10

# %%
new_df.drop("Mehmet") #row silecek çünkü axis belirtmedim ve default değeri sıfır yani row
# Out:
#           Salary       Age  Seniority  Mehmet
# Atil    0.146921 -1.037822  -0.904319      10
# Zeynep  1.356170 -0.461483   0.158498      10
# Atlas  -1.194993 -0.723737  -1.193815      10

# %%
new_df.drop("Mehmet", axis=1, inplace=True) #column atacak

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df.drop("Mehmet", axis=0)
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.146921 -1.037822  -0.904319
# Zeynep  1.356170 -0.461483   0.158498
# Atlas  -1.194993 -0.723737  -1.193815
# Mehmet -0.981229  0.739008  -0.997683

# %%
new_df.loc["Atlas"]
# Out:
# Salary      -1.194993
# Age         -0.723737
# Seniority   -1.193815
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"]
# Out:
# np.float64(-1.1949925399040877)

# %%
new_df.loc["Atlas","Salary"] #same result diffwerent sytntax
# Out:
# np.float64(-1.1949925399040877)

# %%
new_df.loc["Atlas","Salary"] = 100 #yeniden tanımlayabilirm

# %%
new_df #atlasın maaşı 100 oldu
# Out:
#             Salary       Age  Seniority
# Atil      0.146921 -1.037822  -0.904319
# Zeynep    1.356170 -0.461483   0.158498
# Atlas   100.000000 -0.723737  -1.193815
# Mehmet   -0.981229  0.739008  -0.997683

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Atil      True  False      False
# Zeynep    True  False       True
# Atlas     True  False      False
# Mehmet   False   True      False

# %%
boolean_frame =new_df > 0
new_df[boolean_frame]
# Out:
#             Salary       Age  Seniority
# Atil      0.146921       NaN        NaN
# Zeynep    1.356170       NaN   0.158498
# Atlas   100.000000       NaN        NaN
# Mehmet         NaN  0.739008        NaN

# %%
new_df[new_df > 0]
# Out:
#             Salary       Age  Seniority
# Atil      0.146921       NaN        NaN
# Zeynep    1.356170       NaN   0.158498
# Atlas   100.000000       NaN        NaN
# Mehmet         NaN  0.739008        NaN

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.146921 -1.037822  -0.904319
# Zeynep    1.356170 -0.461483   0.158498
# Atlas   100.000000 -0.723737  -1.193815
# Mehmet   -0.981229  0.739008  -0.997683

# %%
new_df[new_df["Salary"]>1] #maaşı biden büyük olan sadece atlas var
# Out:
#            Salary       Age  Seniority
# Zeynep    1.35617 -0.461483   0.158498
# Atlas   100.00000 -0.723737  -1.193815

# %%
new_df[new_df["Age"]>0]
# Out:
#           Salary       Age  Seniority
# Mehmet -0.981229  0.739008  -0.997683

# %% [markdown]
# # **DataFrame Index Mantığı**

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.146921 -1.037822  -0.904319
# Zeynep    1.356170 -0.461483   0.158498
# Atlas   100.000000 -0.723737  -1.193815
# Mehmet   -0.981229  0.739008  -0.997683

# %%
new_df.reset_index() #indexleri göserir ve ayrı kolon açar
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    0.146921 -1.037822  -0.904319
# 1  Zeynep    1.356170 -0.461483   0.158498
# 2   Atlas  100.000000 -0.723737  -1.193815
# 3  Mehmet   -0.981229  0.739008  -0.997683

# %%
new_df #kalıcı bir değişiklik değil
# Out:
#             Salary       Age  Seniority
# Atil      0.146921 -1.037822  -0.904319
# Zeynep    1.356170 -0.461483   0.158498
# Atlas   100.000000 -0.723737  -1.193815
# Mehmet   -0.981229  0.739008  -0.997683

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    0.146921 -1.037822  -0.904319
# 1  Zeynep    1.356170 -0.461483   0.158498
# 2   Atlas  100.000000 -0.723737  -1.193815
# 3  Mehmet   -0.981229  0.739008  -0.997683

# %%
#reset_frame.loc["Atil"] #error verecek çünkü artık index atıl değil

# %%
reset_frame.loc[0] #atılı verecek
# Out:
# index            Atil
# Salary       0.146921
# Age         -1.037822
# Seniority   -0.904319
# Name: 0, dtype: object

# %%
reset_frame.iloc[0] #yine aynı
# Out:
# index            Atil
# Salary       0.146921
# Age         -1.037822
# Seniority   -0.904319
# Name: 0, dtype: object

# %%
new_indices = ["Ati", "Zey", "Atl", "Meh"] #bu listeyi eklemek istiyorum

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Atil      0.146921 -1.037822  -0.904319      Ati
# Zeynep    1.356170 -0.461483   0.158498      Zey
# Atlas   100.000000 -0.723737  -1.193815      Atl
# Mehmet   -0.981229  0.739008  -0.997683      Meh

# %%
new_df.set_index("NewIndex", inplace=True) #artık indexler NewIndex listesi

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Ati         0.146921 -1.037822  -0.904319
# Zey         1.356170 -0.461483   0.158498
# Atl       100.000000 -0.723737  -1.193815
# Meh        -0.981229  0.739008  -0.997683

# %%
new_df.loc["Ati"]
# Out:
# Salary       0.146921
# Age         -1.037822
# Seniority   -0.904319
# Name: Ati, dtype: float64

# %%
#MULTI INDEX

# %%
first_index = ["Simpson", "Simpson", "Simpson", "South Park", "South Park", "South Park"]

# %%
inner_index = ["Homer", "Bart", "Marge", "Cartman", "Kenny", "Kyle"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index=zipped_index, columns=["Salary", "Age"])

# %%
big_df
# Out:
#                     Salary  Age
# Simpson    Homer       1.0  1.0
#            Bart        1.0  1.0
#            Marge       1.0  1.0
# South Park Cartman     1.0  1.0
#            Kenny       1.0  1.0
#            Kyle        1.0  1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
#big_df.loc["Homer"] # error verecek çünkü homera ulaşmam için ilk önce smpsona ulaşmam gerek

# %%
big_df.loc["Simpson"].loc["Homer"] #en dıştaki indexten en içe doğru.
# Out:
# Salary    1.0
# Age       1.0
# Name: Homer, dtype: float64
