# %%
# %%writefile myfile.txt
# test 1
# test 2
# test 3
# Out:
# Overwriting myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.read() #yukarıda içerik sonuna gelmiş oluyor bu yüzden boş
# Out:
# ''

# %%
myFile.seek(0) #bir daha başa aldık ama tek seferlik!
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.read() #bir daha okumak istersek bir kere daha seek yapmak zorundayız
# Out:
# ''

# %%
myFile.close()

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read() #okuduğumuzu bir değişkende kaydettik

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
with open("myfile.txt",mode="w") as myNewFile:
    myNewFile.write("test 4")

# %%
myNewFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='utf-8'>

# %%
with open("myfile.txt",mode="r") as myFile2:
    myContent = myFile2.read()

# %%
myContent
# Out:
# 'test 4'

# %% [markdown]
# # **w -> write, r->read, a->append**
#
# ---

# %%
with open("myfile.txt",mode="a") as myNewFile3:
    myNewFile3.write("test 5")

# %%
with open("myfile.txt",mode="r") as myNewFile4:
    myContent = myNewFile4.read()

# %%
myContent
# Out:
# 'test 4test 5test 5'
