# %% [markdown]
# # **SÖZLÜKLER** DICTIONARY

# %%
#key - value pairing

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [100,150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100,"apple":150} #key:value

# %%
type(fitness_dictionary) #dictionary
# Out:
# dict

# %%
fitness_dictionary["banana"] #anahtarı yazabilirim sadece, 100(value) yazılmaz
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary.keys() #anahtar elemanları verir
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values() #value elements
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values()) # turns the dictionary values into list
# Out:
# [100, 150]

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150}

# %%
fitness_dictionary["banana"] = 200 #mutability (value değiştirebiliriz)

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300 #we can add keys with values

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
help(fitness_dictionary.get) #to avoid errors (get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
fitness_dictionary.get("appl",0) #to avoid errors we use get
# Out:
# 0

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
my_dictionary = {100:"a",200:"b",300:"c"}

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_dictionary[200]
# Out:
# 'b'

# %%
my_dictionary = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
my_dictionary["key1"]
# Out:
# 'value1'

# %%
my_mixed_dictionary = {"key1":100,"key2":3.14,"key3":[10,20,30]} #key ve value tipleri farklı olabilir;

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}} #nested dictionary

# %%
last_dictionary["k2"][2]
# Out:
# 30

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %% [markdown]
# # **SETS**   (KÜMELER)

# %% [markdown]
# - setlerde index mantığı yok
# - setlerde bir eleman sadece bir kere bulunabilir

# %%
#unique elements, unordered

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet = set(myList) #turning the list into set

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10) #adding an exist element will not change the output

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet.add(50) # 50 not exist,

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2) #union() adds the two sets together
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2) #common elements
# Out:
# {30, 40, 50}

# %%
countryList = ["de","fr","tr","fr","tr","tr","de","nl","de","tr"]

# %%
len(countryList)
# Out:
# 10

# %%
len(set(countryList))
# Out:
# 4

# %%
emptyList = []

# %%
emptyList.append(10) #10 ekle
emptyList.append(20) #20 ekle
emptyList.append(30) #30 ekle

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptySet = {} #sözlük gibiymiş gibi algılanır süslü parantezden dolayı

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set() #sözlük gibi algılanmaması için bu şekilde yapılır

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
emptyList = list()

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
emptyDictionary = dict()

# %%
emptyDictionary["a"] = 10
emptyDictionary["b"] = 20

# %%
emptyDictionary
# Out:
# {'a': 10, 'b': 20}

# %% [markdown]
# # **TUPLES**

# %% [markdown]
# - immutable (sonradan index değişimi yapamam)
# - listeye çok benzer ama liste kadar esnek değil

# %%
myList = [10,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %%
#tuple

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
#myTuple[0] = 100
#immutability

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1

# %%
resultTuple = (10,100,20)

# %%
resultTuple
# Out:
# (10, 100, 20)

# %%
resultList = list(resultTuple)

# %%
resultList
# Out:
# [10, 100, 20]

# %% [markdown]
# # **BOOLEAN**

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean  = False

# %%
5>3
# Out:
# True

# %%
3>5
# Out:
# False

# %%
age = input("enter age:")
int(age) >= 18
# Out:
# enter age:19
# True
