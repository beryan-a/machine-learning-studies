# %%
#yeni bir özellik, aşırı önemli değil (karşıma çıkar diye)

# %%
name: str = "Atıl"
age: int = 30
is_student: bool = False

# %%
def add_numbers(a: int, b: int) -> int: #birinci ve ikinci parametre integer olacak sonuç da integer olmalı
    return a + b

# %%
add_numbers(20,30)
# Out:
# 50

# %%
#python 3.10 and above
def process_value(value: int | str) -> str:
    if isinstance(value, int): #isinstance fonksiyonu verilen değişkenin türünü kontrol etmeyi sağlar
        return f"Processed integer: {value}"
    else:
        return f"Processed string: {value}"

# %%
process_value(10)
# Out:
# 'Processed integer: 10'

# %%
process_value("10")
# Out:
# 'Processed string: 10'

# %%
#python 3.9 and above
from typing import List

def sum_list(numbers: List[int]) -> int:
    return sum(numbers)

numbers = [1, 2, 3, 4]
total = sum_list(numbers)

# %%
total
# Out:
# 10
